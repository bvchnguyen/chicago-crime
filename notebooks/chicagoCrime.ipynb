# %% [markdown]
# Name: Chicago Crime
# Bach Nguyen, Matthew Mayer, Samyak Ghimire, Suyogya Poudel

# %%
# Import all the libraries needed for the project
# Can be removed if not needed later on

import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import math as math

# %%
def read_data(fileName):
    # Read the data from the csv file
    df = pd.read_csv(fileName)
    return df

# %%
data_read = read_data('./data/Crimes_-_2001_to_Present.csv')
display(data_read)
print(data_read.columns)
# Out:
#                ID Case Number                    Date  \
# 0        11037294    JA371270  03/18/2015 12:00:00 PM
# 1        11646293    JC213749  12/20/2018 03:00:00 PM
# 2        11645836    JC212333  05/01/2016 12:25:00 AM
# 3        11645959    JC211511  12/20/2018 04:00:00 PM
# 4        11645601    JC212935  06/01/2014 12:01:00 AM
# ...           ...         ...                     ...
# 7908438  12131776    JD327752  08/10/2020 08:30:00 PM
# 7908439  12082414    JD269218  06/18/2020 09:00:00 PM
# 7908440  12118237    JD311791  07/27/2020 03:02:00 PM
# 7908441  12142591    JD340297  08/14/2020 03:00:00 PM
# 7908442  12002171    JD177406  03/06/2020 02:00:00 PM
#
#                                        Block  IUCR         Primary Type  \
# 0                          0000X W WACKER DR  1153   DECEPTIVE PRACTICE
# 1                       023XX N LOCKWOOD AVE  1154   DECEPTIVE PRACTICE
# 2                        055XX S ROCKWELL ST  1153   DECEPTIVE PRACTICE
# ...

# %%
def data_preprocessing(fileName):

    # Read the data from the csv file
    # prepocessing the data
    # See project proposal for details to consider

    df = pd.read_csv(fileName)
   
    # Drop the rows that have duplicate values
    df = df.drop_duplicates()
    # Drop the rows that have missing values / NaN values
    df = df.dropna()

    # Drop the columns that are not needed, add more if needed
    df = df.drop(['IUCR'])
    df = df.drop(['FBI Code'])


    # Consider dropping location since it's just Longitude and Latitude combined
    df = df.drop(['Location'])

    # Split the date and time into two columns
    df['Date'] = df['Date'].str.split(' ').str[0]
    df['Time of Crime'] = df['Date'].str.split(' ').str[1]

    return df
